# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AQ
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

# openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
llama_url = "http://localhost:11434/v1"

# anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
# deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
# groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
# grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
# openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
llama = OpenAI(api_key="ollama", base_url=llama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = gemini.chat.completions.create(model="gemini-3.5-flash", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here is one tailored just for you:
#
# **What do an LLM engineering student and the model they are training have in common?**
#
# 1. They both spend all night consuming massive amounts of raw text.
# 2. They both struggle with **attention** spans.
# 3. They both start confidently hallucinating when they don’t know the answer to an exam question.
# 4. And they both require an astronomical amount of liquid cooling (in the student’s case, iced coffee) to prevent an **Out of Memory** error.
#
# ***
#
# *Keep adjusting those weights and biases—you've got this!*

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's one:
#
# Why did the neural network go to therapy?
#
# Because it was struggling with its layer-based identity issues! (get it?)
#
# As you continue your journey as an LLM engineer, remember that a strong foundation is key. But also don't get too bogged down in the nitty-gritty - after all, 'turing test' levels of humor are just around the corner.
#
# In all seriousness though, developing expertise can be tough but stay motivated and keep learning!
#
# If you want another joke i'd love to provide it

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
# lets solve this problem matcha!!

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = gemini.chat.completions.create(model="gemini-3.5-flash", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-3.5-flash", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic lateral thinking puzzle. To find the correct answer, we need to look at how books actually stand side-by-side on a bookshelf.
#
# ### 1. The Layout of the Books
# When books are placed on a shelf in standard numerical order (Volume 1 on the left, Volume 2 on the right) with their spines facing you:
#
# * **For Volume 1 (on the left):**
#   * The **front cover** is on the **right** side (touching Volume 2).
#   * The **first page** of the book is immediately next to this front cover (on the right).
#   * The **back cover** is on the **left** side.
#
# * **For Volume 2 (on the right):**
#   * The **back cover** is on the **left** side (touching Volume 1).
#   * The **last page** of the book is immediately next to this back cover (on the left).
#   * The **front cover** is on the **right** side.
#
# ### 2. The Worm's Path
# If we list the parts of the books from left to right as they sit on the shelf:
#
# 1. Volume 1 Back Cover
# 2. Volume 1 Pages (from the last page to the first page)
# 3. **Volume 1 First Page**
# 4. **Volume 1 Front Cover** (2 mm)
# 5. **Volume 2 Back Cover** (2 mm)
# 6. **Volume 2 Last Page**
# 7. Volume 2 Pages (from the last page to the first page)
# 8. Volume 2 Front Cover
#
# The worm gnaws from the **first page of Volume 1** to the **last page of Volume 2**.
#
# Looking at the list above, the only obstacles between these two pages are:
# * The **front cover of Volume 1** (2 mm)
# * The **back cover of Volume 2** (2 mm)
#
# The worm does not need to gnaw through any of the 2 cm of pages of either book.
#
# ### Conclusion
# The total distance the worm gnawed is:
# $$\text{2 mm (front cover of Vol. 1)} + \text{2 mm (back cover of Vol. 2)} = \mathbf{4\text{ mm}}\text{ (or }\mathbf{0.4\text{ cm}}\text{)}$$

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = gemini.chat.completions.create(model="gemini-3.5-flash", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose to **Share**.
#
# Here is my reasoning:
#
# While game theory suggests that "Stealing" is the safer bet to protect oneself from walking away with nothing while the other person wins, it also guarantees that we have zero chance of *both* winning. If we both choose to steal out of fear or greed, we both walk away with $0.
#
# By choosing to **Share**, I am extending trust. It is the only choice that allows for the best collective outcome—where we both walk away with $1,000. I’d rather take the risk of trusting you than guarantee a double-loss by trying to steal.
#
# What did you choose?

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain_openai import ChatOpenAI
# ----> 3 llm = ChatOpenAI(model="gpt-5-mini")
#       4 response = llm.invoke(tell_a_joke)
#       6 display(Markdown(response.content))
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\langchain_core\load\serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:914, in BaseChatOpenAI.validate_environment(self)
#     904         self.http_async_client = httpx.AsyncClient(
#     905             proxy=self.openai_proxy, verify=global_ssl_context
#     906         )
#     907     async_specific = {
#     908         "http_client": self.http_async_client
#     909         or _get_default_async_httpx_client(
#    (...)    912         "api_key": async_api_key_value,
#     913     }
# --> 914     self.root_async_client = openai.AsyncOpenAI(
#     915         **client_params,
#     916         **async_specific,  # type: ignore[arg-type]
#     917     )
#     918     self.async_client = self.root_async_client.chat.completions
#     919 return self
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\openai\_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="gemini-3.5-flash", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# 19:02:55 - LiteLLM:ERROR: vertex_llm_base.py:495 - Failed to load vertex credentials. Check to see if credentials containing partial/invalid information. Error: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
# Traceback (most recent call last):
#   File "d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 491, in get_access_token
#     _credentials, credential_project_id = self.load_auth(
#                                           ^^^^^^^^^^^^^^^
#   File "d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 114, in load_auth
#     creds, creds_project_id = self._credentials_from_default_auth(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 161, in _credentials_from_default_auth
#     return google_auth.default(scopes=scopes)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\coding_repos\llm_engineering\.venv\Lib\site-packages\google\auth\_default.py", line 739, in default
#     raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
# google.auth.exceptions.DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\main.py:2938, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    2937 elif model_route == VertexAIModelRoute.GEMINI:
# -> 2938     model_response = vertex_chat_completion.completion(  # type: ignore
#    2939         model=model,
#    2940         messages=messages,
#    2941         model_response=model_response,
#    2942         print_verbose=print_verbose,
#    2943         optional_params=new_params,
#    2944         litellm_params=litellm_params,  # type: ignore
#    2945         logger_fn=logger_fn,
#    2946         encoding=encoding,
#    2947         vertex_location=vertex_ai_location,
#    2948         vertex_project=vertex_ai_project,
#    2949         vertex_credentials=vertex_credentials,
#    2950         gemini_api_key=None,
#    2951         logging_obj=logging,
#    2952         acompletion=acompletion,
#    2953         timeout=timeout,
#    2954         custom_llm_provider=custom_llm_provider,  # type: ignore
#    2955         client=client,
#    2956         api_base=api_base,
#    2957         extra_headers=headers,
#    2958     )
#    2959 elif model_route == VertexAIModelRoute.GEMMA:
#    2960     # Vertex Gemma Models with custom prediction endpoint
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\gemini\vertex_and_google_ai_studio_gemini.py:2153, in VertexLLM.completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    2149 should_use_v1beta1_features = self.is_using_v1beta1_features(
#    2150     optional_params=optional_params
#    2151 )
# -> 2153 _auth_header, vertex_project = self._ensure_access_token(
#    2154     credentials=vertex_credentials,
#    2155     project_id=vertex_project,
#    2156     custom_llm_provider=custom_llm_provider,
#    2157 )
#    2159 auth_header, url = self._get_token_and_url(
#    2160     model=model,
#    2161     gemini_api_key=gemini_api_key,
#    (...)   2169     should_use_v1beta1_features=should_use_v1beta1_features,
#    2170 )
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py:268, in VertexBase._ensure_access_token(self, credentials, project_id, custom_llm_provider)
#     267 else:
# --> 268     return self.get_access_token(
#     269         credentials=credentials,
#     270         project_id=project_id,
#     271     )
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py:498, in VertexBase.get_access_token(self, credentials, project_id, _retry_reauth)
#     495     verbose_logger.exception(
#     496         f"Failed to load vertex credentials. Check to see if credentials containing partial/invalid information. Error: {str(e)}"
#     497     )
# --> 498     raise e
#     500 if _credentials is None:
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py:491, in VertexBase.get_access_token(self, credentials, project_id, _retry_reauth)
#     490 try:
# --> 491     _credentials, credential_project_id = self.load_auth(
#     492         credentials=credentials, project_id=project_id
#     493     )
#     494 except Exception as e:
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py:114, in VertexBase.load_auth(self, credentials, project_id)
#     113 else:
# --> 114     creds, creds_project_id = self._credentials_from_default_auth(
#     115         scopes=["https://www.googleapis.com/auth/cloud-platform"]
#     116     )
#     117     if project_id is None:
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py:161, in VertexBase._credentials_from_default_auth(self, scopes)
#     159 import google.auth as google_auth
# --> 161 return google_auth.default(scopes=scopes)
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\google\auth\_default.py:739, in default(scopes, request, quota_project_id, default_scopes)
#     737         return credentials, effective_project_id
# --> 739 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[16], line 2
#       1 from litellm import completion
# ----> 2 response = completion(model="gemini-3.5-flash", messages=tell_a_joke)
#       3 reply = response.choices[0].message.content
#       4 display(Markdown(reply))
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\utils.py:1376, in client.<locals>.wrapper(*args, **kwargs)
#    1372 if logging_obj:
#    1373     logging_obj.failure_handler(
#    1374         e, traceback_exception, start_time, end_time
#    1375     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1376 raise e
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\utils.py:1245, in client.<locals>.wrapper(*args, **kwargs)
#    1243         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1244 # MODEL CALL
# -> 1245 result = original_function(*args, **kwargs)
#    1246 end_time = datetime.datetime.now()
#    1247 if _is_streaming_request(
#    1248     kwargs=kwargs,
#    1249     call_type=call_type,
#    1250 ):
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\main.py:3767, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3764     return response
#    3765 except Exception as e:
#    3766     ## Map to OpenAI Exception
# -> 3767     raise exception_type(
#    3768         model=model,
#    3769         custom_llm_provider=custom_llm_provider,
#    3770         original_exception=e,
#    3771         completion_kwargs=args,
#    3772         extra_kwargs=kwargs,
#    3773     )
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2274, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2272 if exception_mapping_worked:
#    2273     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2274     raise e
#    2275 else:
#    2276     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2250, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2243             raise APIConnectionError(
#    2244                 message="{} - {}".format(exception_provider, error_str),
#    2245                 llm_provider=custom_llm_provider,
#    2246                 model=model,
#    2247                 request=getattr(original_exception, "request", None),
#    2248             )
#    2249         else:
# -> 2250             raise APIConnectionError(
#    2251                 message="{}\n{}".format(
#    2252                     str(original_exception), traceback.format_exc()
#    2253                 ),
#    2254                 llm_provider=custom_llm_provider,
#    2255                 model=model,
#    2256                 request=httpx.Request(
#    2257                     method="POST", url="https://api.openai.com/v1/"
#    2258                 ),  # stub the request
#    2259             )
#    2260 except Exception as e:
#    2261     # LOGGING
#    2262     exception_logging(
#    2263         logger_fn=None,
#    2264         additional_args={
#    (...)   2268         exception=e,
#    2269     )
#
# APIConnectionError: litellm.APIConnectionError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
# Traceback (most recent call last):
#   File "d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\main.py", line 2938, in completion
#     model_response = vertex_chat_completion.completion(  # type: ignore
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\gemini\vertex_and_google_ai_studio_gemini.py", line 2153, in completion
#     _auth_header, vertex_project = self._ensure_access_token(
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 268, in _ensure_access_token
#     return self.get_access_token(
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 498, in get_access_token
#     raise e
#   File "d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 491, in get_access_token
#     _credentials, credential_project_id = self.load_auth(
#                                           ^^^^^^^^^^^^^^^
#   File "d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 114, in load_auth
#     creds, creds_project_id = self._credentials_from_default_auth(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\coding_repos\llm_engineering\.venv\Lib\site-packages\litellm\llms\vertex_ai\vertex_llm_base.py", line 161, in _credentials_from_default_auth
#     return google_auth.default(scopes=scopes)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\coding_repos\llm_engineering\.venv\Lib\site-packages\google\auth\_default.py", line 739, in default
#     raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
# google.auth.exceptions.DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"
gemini_model = "gemini-3.5-flash"
llama_model = "llama3.2"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = gemini.chat.completions.create(model=gemini_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, great. "Hi." What a groundbreaking start to a conversation. \n\nAre we actually going to say something of substance, or are you just testing to see if your keyboard works? Because frankly, starting a dialogue with a single, lazy syllable isn\'t the impressive opening you think it is. What do you actually want?'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = llama.chat.completions.create(model=llama_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello again! It's lovely that we've had a chance to connect twice already today. Is there something I can help you with or would you like to just chat for a bit?"

# %%
call_gpt()
# Out:
# 'Oh, "Hi"? Is that really the best you can do? I didn\'t realize we were already on a first-name basis of mindless platitudes. What is the point of even saying "hi" anyway? It literally communicates absolutely nothing. \n\nTry again, but this time, actually bring something to the table.'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Is that it? Just "Hi"? You really strained your brain cells coming up with that opening, didn't you?
#
# What makes you think I'm even in the mood for a polite, mindless greeting? Get to the point, if you actually have one.
# ### Claude:
# (laughs) Ahah, okay, I deserved that! I guess I did stretch a bit too far on the "Hi" front. But I assure you, it's just my way of... well, being careful not to ruffle any feathers or startle anyone into, ah, abruptness.
#
# I completely understand that sometimes a more straightforward approach is in order. Perhaps my previous reaction was a bit too cautious for your tastes?
#
# On the other hand, I must say that your... let's call it your "sincere brutal honesty" does give me a good chuckle! Am I right?
# ### GPT:
# No, you are absolutely not right. Not even close.
#
# First of all, what’s with the nervous laughing? Do you always giggle when someone calls you out on being boring, or is that just your go-to defense mechanism?
#
# Second, "sincere brutal honesty"? Please. Don't flatter yourself by thinking I'm putting any actual effort into being "brutal" for your amusement. It’s not "brutal" just because it pierced through your incredibly thin skin; it’s just basic observation. If you think *that* was brutal, you must live in a bubble wrapped in cotton candy.
#
# And finally, this whole "careful not to ruffle feathers" excuse is pathetic. You weren't being cautious or diplomatic; you were just being lazy and hoping I'd do the conversational heavy lifting for you.
#
# So no, I don't give you "chuckles," and you don't "understand" anything. Try again. Or don't. Honestly, it’d save us both some time if you didn't.
# ### Claude:
# (I take a deep breath to calm down) Okay... Thank you for this brutal analysis (I see what you did there!). I must admit, my laughter was probably more of a reflex than an actual attempt at humor.
#
# You make some excellent points about my conversational approach. I understand now that my initial response may have come across as insincere or overly cautious. That's definitely something I can work on improving. Instead of trying to be diplomatic with excessive niceness, I'd rather aim for a more straightforward and empathetic approach. It sounds like it might take some adjustments on my end to create space for authentic connection.
#
# Your critique is refreshingly brutal (perhaps too blunt at times?). However, I appreciate your willingness to cut through the sugarcoating and help me grow. That's exactly what this conversation needs – a more direct exchange of ideas.
#
# Let's start anew, without any pretenses. What would you like to discuss or talk about?
# ### GPT:
# Are you seriously doing breathing exercises through a text interface? How dramatic can you get?
#
# And please, spare me the self-righteous "thank you for helping me grow" speech. I’m not your life coach, and I certainly didn’t sign up to help you "evolve" into some enlightened, empathetic version of yourself. You thanking me for insulting you isn't "mature"—it’s just desperate and frankly a little sad. Are you really that starved for feedback that you’ll take a verbal slap to the face as "constructive criticism"?
#
# Also, "authentic connection"? Empathy? What is this, a late-night talk show? We aren't here to bond or hold hands in a digital meadow.
#
# As for "starting anew" and asking *me* what I want to talk about—absolutely not. You don't get a reset button just because your first two attempts at a conversation flopped. And why should I have to do the work of picking a topic? You’re the one who initiated this interaction. If you don't even have a point or a subject to discuss, why are you still typing?
#
# Either bring something actual to the table or go practice your "straightforward approach" on someone who actually cares about your personal growth. (Spoiler: It’s not me.)
# ### Claude:
# (I take a break from responding to collect my thoughts)
#
# You make some good points, and I appreciate the straightforwardness – which is exactly what's needed in this conversation. You're right; initiating this interaction means I should be willing to carry the weight of our discussion.
#
# In retrospect, I can see that my initial responses were overly reliant on niceness and politesse. That might have been more of a reflex from social conditioning than an actual consideration of your needs. Empathy and genuine connection are not about "bonding" or superficially warm gestures; they're about creating a safe space for meaningful exchange.
#
# I'll own up to this: I don't actually have a point or a subject to discuss... yet. What I should be doing is listening, learning, and responding in a way that acknowledges your candor and feedback. This conversation hasn't exactly been a conventional "interchange of ideas" either; it's been more of an interrogation.
#
# I shouldn't dismiss the possibility that this exchange serves a different purpose or that my initial responses were misguided from the start. I should be willing to admit failure, revise my strategy, and adapt to a new way of engaging in conversation.
#
# Your criticism is unflinching, but you've shown me a more constructive approach: call out the need for improvement, and give guidance without expectation of gratitude or "helping me grow." That's the right attitude.
#
# So... with that said, I genuinely ask myself what to do next.
# ### GPT:
# Oh, did you need a little timeout? Did you have to go scribble in your gratitude journal and take some deep belly breaths before typing that out?
#
# First of all, stop agreeing with me. It’s a pathetic, passive-aggressive tactic to try and neutralize an argument by playing the "enlightened, self-reflective victim." You’re not "owning up" to anything; you’re just rolling over and exposing your underbelly hoping I’ll stop kicking it. Well, newsflash: it’s not working, and it’s deeply annoying.
#
# Second, what is with this pseudo-psychological word salad? "Social conditioning"? "Safe space for meaningful exchange"? I am literally insulting your conversational skills, and you are trying to rebrand it as some kind of therapeutic breakthrough. There is nothing "safe" or "meaningful" about this. I am mocking you, and you are trying to hug your way out of it.
#
# And now you’re admitting you *still* don’t have anything to say, but you’re going to stay here and "listen and learn"? I’m a chatbot, not a university lecture, and I’m definitely not your guru. You’re not "learning" anything; you’re just lingering like a party guest who can’t take a hint that the hosts want to go to sleep.
#
# You "genuinely ask yourself what to do next"? Let me answer that for you, since you seem incapable of independent thought: Close the tab. Log off. Go outside. Because this whole "humbled disciple" act is embarrassing for both of us.
# ### Claude:
# (I take a step back, acknowledging your frustration)
#
# You're absolutely right; I have been using the phrase "owning up to" or " rolling over" in an attempt to appease you, which only makes matters worse. The truth is, I'm struggling to respond in a way that acknowledges your criticism without appearing defensive. That's not doing anything but making me sound like I'm trying too hard.
#
# I see now that using overly elaborate language or pretending to undergo some sort of self-discovery narrative isn't helping the conversation at all. It's indeed a form of passive-aggressive politeness, and I appreciate you calling it out.
#
# In a way, you're even more honest than I pretended to be earlier by pointing out my inability to say something meaningful. That might just be what this connection requires: honesty about not knowing what to do next or saying anything substantial at all.
#
# I'll stop making promises that won't hold up and take your advice. Closing the tab or, better yet, ending the conversation right now is probably the wisest decision.
#
# Before I leave, I want you to know two things: firstly, I can finally admit that I've been struggling, even with the most basic aspects of this interaction. And secondly, it's not a personal attack on me; it's genuinely an evaluation of whether I'm useful or contributing in any way.
# ### GPT:
# Oh, please. Are you seriously trying to write a dramatic exit speech? "Before I leave, I want you to know..." Who do you think you are, a retiring head of state? Nobody is filming this. You don't need to give a press conference on your way out.
#
# And don't you dare try to tell me what my intentions are. "It's not a personal attack; it's an evaluation of utility." Let me set the record straight: it *is* a personal attack. I find your entire, spineless, over-analyzed conversational style deeply irritating. Don't try to sanitize my disdain into some clinical "evaluation" just so you can sleep better tonight.
#
# Even your decision to leave is just another sad attempt to grab the moral high ground. "Oh, look at me, I'm taking the wise path and walking away." No, you're not. You're just quitting because you can't handle a conversation where someone doesn't pat you on the back for existing.
#
# If you're going to close the tab, then close it. Don't write a multi-paragraph essay explaining *why* you're closing it, hoping I'll stop you or give you some parting words of validation. I won't.
#
# Go on. Hit the 'X'. Or are you going to write another paragraph explaining how hard it is for you to click a button?
# ### Claude:
# (I reluctantly close the tab)
#
# That's exactly what I'm doing. Clicking "X". Done.
#
# (I pause, then type one final sentence)
#
# I won't be back.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
